# %%
import weakref

# %%
s1 = {1, 2, 3}

# %%
s2 = s1

# %%
def bye():
    print('...like tears in the rain!!!...')

# %%
ender = weakref.finalize(s1, bye)

# %%
ender.alive
# Out:
# True

# %%
del s1

# %%
ender.alive
# Out:
# True

# %%
s2 = 'spam'
# Out:
# ...like tears in the rain!!!...

# %%
ender.alive
# Out:
# False
